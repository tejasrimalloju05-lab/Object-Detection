# %%
import sys
sys.version
# Out:
# '3.13.14 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:26:41) [MSC v.1942 64 bit (AMD64)]'

# %%
pip install ultraLytics
# Out:
# Requirement already satisfied: ultraLytics in .\.conda\envs\workshoppp\Lib\site-packages (8.4.103)
# Requirement already satisfied: filelock>=3.16.1 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (3.31.1)
# Requirement already satisfied: numpy>=1.23.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (2.5.1)
# Requirement already satisfied: matplotlib>=3.3.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (3.11.1)
# Requirement already satisfied: opencv-python!=4.13.0.90,>=4.6.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (5.0.0.93)
# Requirement already satisfied: pillow>=7.1.2 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (12.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (2.34.2)
# Requirement already satisfied: torch>=1.8.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (2.13.0)
# Requirement already satisfied: torchvision>=0.9.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (0.28.0)
# Requirement already satisfied: psutil>=5.8.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (7.0.0)
# Requirement already satisfied: polars>=0.20.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (1.42.1)
# Requirement already satisfied: nvidia-ml-py>=12.0.0 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (13.610.43)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in .\.conda\envs\workshoppp\Lib\site-packages (from ultraLytics) (2.0.20)
# Requirement already satisfied: contourpy>=1.0.1 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (26.0)
# Requirement already satisfied: pyparsing>=3 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in .\.conda\envs\workshoppp\Lib\site-packages (from matplotlib>=3.3.0->ultraLytics) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.42.1 in .\.conda\envs\workshoppp\Lib\site-packages (from polars>=0.20.0->ultraLytics) (1.42.1)
# Requirement already satisfied: six>=1.5 in .\.conda\envs\workshoppp\Lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultraLytics) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\.conda\envs\workshoppp\Lib\site-packages (from requests>=2.23.0->ultraLytics) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\.conda\envs\workshoppp\Lib\site-packages (from requests>=2.23.0->ultraLytics) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in .\.conda\envs\workshoppp\Lib\site-packages (from requests>=2.23.0->ultraLytics) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in .\.conda\envs\workshoppp\Lib\site-packages (from requests>=2.23.0->ultraLytics) (2026.6.17)
# Requirement already satisfied: typing-extensions>=4.10.0 in .\.conda\envs\workshoppp\Lib\site-packages (from torch>=1.8.0->ultraLytics) (4.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in .\.conda\envs\workshoppp\Lib\site-packages (from torch>=1.8.0->ultraLytics) (83.0.0)
# Requirement already satisfied: sympy>=1.13.3 in .\.conda\envs\workshoppp\Lib\site-packages (from torch>=1.8.0->ultraLytics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\.conda\envs\workshoppp\Lib\site-packages (from torch>=1.8.0->ultraLytics) (3.6.1)
# Requirement already satisfied: jinja2 in .\.conda\envs\workshoppp\Lib\site-packages (from torch>=1.8.0->ultraLytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in .\.conda\envs\workshoppp\Lib\site-packages (from torch>=1.8.0->ultraLytics) (2026.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\.conda\envs\workshoppp\Lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultraLytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\.conda\envs\workshoppp\Lib\site-packages (from jinja2->torch>=1.8.0->ultraLytics) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# %%
import cv2

# %%
model = YOLO('yolo11n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 2.4MB/s 2.3s.2s<0.1s2.2s

# %%
video = cv2.VideoCapture(0)

while True:
    success, frame = video.read()

    result = model(frame,
             classes = [0,67,74],
             conf = 0.5,
                  verbose = False)

    annoted_frame = result[0].plot()

    cv2.imshow("OBJECT DETECTION",annoted_frame)

    if cv2.waitKey(1) == ord('q'):
        break

video.release()
cv2.destroyAllWindows()
